# %%
import yfinance as yf
from matplotlib import pyplot as plt

# Load the MSFT Stock closing prices data from Yahoo Finance for the period 2018-01-01 to Latest date
msft = yf.Ticker("MSFT")
hist = msft.history(period="max")
hist = hist[hist.index >= '2018-01-01']
hist = hist[['Close']]
hist = hist.rename(columns={'Close': 'MSFT'})
hist = hist.dropna()
hist
# Out:
#                                  MSFT
# Date
# 2018-01-02 00:00:00-05:00   80.229004
# 2018-01-03 00:00:00-05:00   80.602379
# 2018-01-04 00:00:00-05:00   81.311798
# 2018-01-05 00:00:00-05:00   82.319931
# 2018-01-08 00:00:00-05:00   82.403915
# ...                               ...
# 2023-11-27 00:00:00-05:00  378.609985
# 2023-11-28 00:00:00-05:00  382.700012
# 2023-11-29 00:00:00-05:00  378.850006
# 2023-11-30 00:00:00-05:00  378.910004
# 2023-12-01 00:00:00-05:00  374.510010
#
# [1490 rows x 1 columns]

# %%
# Save the data to a CSV file
hist.to_csv('MSFT.csv')

# %%
# Plot the data
hist.plot(figsize=(10, 5))
plt.title('MSFT Stock Price')
plt.ylabel('Price')
plt.grid()
plt.savefig('MSFT.png')
plt.show()
